# %%
table_base = "ext_novartis.raw"

base_path="/Volumes/ext_novartis/default/files"

# %%
hcp=spark.read.parquet(f"{base_path}/hcp/")
hcp.write.mode("overwrite").format("delta").saveAsTable(f"{table_base}.hcp")

# %%
hco=spark.read.parquet(f"{base_path}/hco/")
hco.write.mode("overwrite").format("delta").saveAsTable(f"{table_base}.hco")

# %%
hcp_hco_relationship=spark.read.parquet(f"{base_path}/hcp_hco_relationship/")
hcp_hco_relationship.write.mode("overwrite").format("delta").saveAsTable(f"{table_base}.hcp_hco_relationship")

# %%
calls=spark.read.parquet(f"{base_path}/calls/")
calls.write.mode("overwrite").format("delta").saveAsTable(f"{table_base}.calls")

# %%
emails=spark.read.parquet(f"{base_path}/emails/")
emails.write.mode("overwrite").format("delta").saveAsTable(f"{table_base}.emails")

# %%
ad_impressions=spark.read.parquet(f"{base_path}/ad_impressions/")
ad_impressions.write.mode("overwrite").format("delta").saveAsTable(f"{table_base}.ad_impressions")

# %%
late_events=spark.read.parquet(f"{base_path}/late_events/")
late_events.write.mode("overwrite").format("delta").saveAsTable(f"{table_base}.late_events")

# %%
cdc_calls=spark.read.parquet(f"{base_path}/cdc_calls/")
cdc_calls.write.mode("overwrite").format("delta").saveAsTable(f"{table_base}.cdc_calls")

# %%
bad_data=spark.read.parquet(f"{base_path}/bad_data/")
bad_data.write.mode("overwrite").format("delta").saveAsTable(f"{table_base}.bad_data")

# %%
campaigns=spark.read.parquet(f"{base_path}/campaigns/")
campaigns.write.mode("overwrite").format("delta").saveAsTable(f"{table_base}.campaigns")
